# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_excel("enhanced_job_role_dataset_1000 (1).xlsx")

# Display top rows
df.head()
#Basic Information
df.info()
df.describe()
df.isnull().sum()

#Check Duplicates
df.duplicated().sum()

#Column Overview
df.columns

#Univariate Analysis
#(Understand distributions)

numeric_cols = df.select_dtypes(include=np.number).columns
for col in numeric_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()
    
#Categorical Analysis

cat_cols = df.select_dtypes(include="object").columns
for col in cat_cols:
    plt.figure(figsize=(6,4))
    sns.countplot(y=df[col], order=df[col].value_counts().index)
    plt.title(f"Count of {col}")
    plt.show()
    
#Correlation Heatmap

plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()


#Outlier Detection (Boxplots)

for col in numeric_cols:
    plt.figure(figsize=(6,4))
    sns.boxplot(df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   S. No.              1000 non-null   int64
#  1   Degree              995 non-null    object
#  2   Major               1000 non-null   object
#  3   GPA                 999 non-null    float64
#  4   Year of Graduation  994 non-null    float64
#  5   Age                 999 non-null    float64
#  6   Gender              994 non-null    object
#  7   Internships         992 non-null    float64
#  8   Previous Job Title  992 non-null    object
#  9   Industry            992 non-null    object
#  10  Skill1              1000 non-null   object
#  11  Skill2              1000 non-null   object
#  12  SoftSkill           1000 non-null   object
#  13  Certification       897 non-null    object
#  14  JobRole             1000 non-null   object
#  15  Work Preference     1000 non-null   object
# dtypes: float64(4), int64(1), object(11)
# memory usage: 125.1+ KB
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 44
#      41 #Correlation Heatmap
#      43 plt.figure(figsize=(10,6))
# ---> 44 sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
#      45 plt.title("Correlation Heatmap")
#      46 plt.show()
#
# File c:\Users\D Kartheek\Desktop\job-role-EDA\venv\Lib\site-packages\pandas\core\frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11074 cols = data.columns
#   11075 idx = cols.copy()
# > 11076 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11078 if method == "pearson":
#   11079     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\D Kartheek\Desktop\job-role-EDA\venv\Lib\site-packages\pandas\core\frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2000 if dtype is not None:
#    2001     dtype = np.dtype(dtype)
# -> 2002 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003 if result.dtype is not dtype:
#    2004     result = np.asarray(result, dtype=dtype)
#
# File c:\Users\D Kartheek\Desktop\job-role-EDA\venv\Lib\site-packages\pandas\core\internals\managers.py:1713, in BlockManager.as_array(self, dtype, copy, na_value)
#    1711         arr.flags.writeable = False
#    1712 else:
# -> 1713     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1714     # The underlying data was copied within _interleave, so no need
#    1715     # to further copy if copy=True or setting na_value
#    1717 if na_value is lib.no_default:
#
# File c:\Users\D Kartheek\Desktop\job-role-EDA\venv\Lib\site-packages\pandas\core\internals\managers.py:1772, in BlockManager._interleave(self, dtype, na_value)
#    1770     else:
#    1771         arr = blk.get_values(dtype)
# -> 1772     result[rl.indexer] = arr
#    1773     itemmask[rl.indexer] = 1
#    1775 if not itemmask.all():
#
# ValueError: could not convert string to float: 'MBA'
